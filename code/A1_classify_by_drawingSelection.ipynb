# %% [markdown]
# # Intro

# %% [markdown]
# Welcome to the interactive 'classification by drawing' notebook!
# This notebook goes through each step and allows you to tune parameters and view how it changes the results.
#
# The notebook proceeds as follows:
#
# 1. **Import** libraries
# 2. Define **paths** to data
# 3. Run data through the **pipeline**. (ROInet embedding + UMAP)
# 4. **Draw** a circle around a region of the UMAP embedding to select as 'good ROIs to keep'
# 5. **Visualize** results
# 6. **Save** results

# %% [markdown]
# ##### If running on google colab:

# %% [markdown]
# - install roicat
#
# After running the cell below, the runtime will restart.

# %% [markdown]
# # Import libraries

# %% [markdown]
# Widen the notebook

# %%
# widen jupyter notebook window
from IPython.display import display, HTML
display(HTML("<style>.container {width:95% !important; }</style>"))
display(HTML("<style>:root { --jp-notebook-max-width: 100% !important; }</style>"))
# Out:
# <style>.container {width:95% !important; }</style>
# <style>:root { --jp-notebook-max-width: 100% !important; }</style>

# %% [markdown]
# Import basic libraries

# %%
from pathlib import Path
import tempfile
import os

import numpy as np
from umap import UMAP

# %% [markdown]
# Import `roicat`

# %%
import roicat

# %% [markdown]
# # Find paths to data

# %% [markdown]
# ##### Prepare list of paths to data

# %% [markdown]
# In this example we are using suite2p output files, but other data types can be used (CaImAn, etc.) \
# See the notebook on ingesting diverse data: https://github.com/RichieHakim/ROICaT/blob/main/notebooks/jupyter/other/demo_custom_data_importing.ipynb
#
# Make a list containing the paths to all the input files.
#
# In this example we are using suite2p, so the following are defined:
# 1. `paths_allStat`: a list to all the stat.npy files
# 2. `paths_allOps`: a list with ops.npy files that correspond 1-to-1 with the stat.npy files

# %%
from path_io import load_session_planes
all_planes = [ 
    p for d in os.listdir('/data')
      for p in load_session_planes(f"/data/{d}") 
]

# %% [markdown]
# **Important parameters**:
#
# - `um_per_pixel` (float):
#     - Resolution. 'micrometers per pixel' of the imaging field of view.

# %%
data_importers = []
for p in all_planes:
    data_importer = roicat.data_importing.Data_roicat()
    try:
        data_importer.set_spatialFootprints([p.rois], um_per_pixel=p.um_per_px)
        data_importer.transform_spatialFootprints_to_ROIImages(out_height_width=(36, 36))
    except IndexError as e:
        print(f"{p.rois.shape}")
        continue

    assert data_importer.check_completeness(verbose=False)['classification_inference'], f"Data object is missing attributes necessary for tracking."
    data_importers.append(data_importer)

ROI_images = [di.ROI_images[0] for di in data_importers]
um_per_pixel = [ di.um_per_pixel[0] for di in data_importers]
# Out:
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# ...
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.
# RH WARNING: spatialFootprints are numpy.ndarray objects. Assuming structure is a list of arrays (1 per session) of shape (n_roi, height, width), converting them to scipy.sparse.csr_matrix objects.
# Completed: Set FOV_height and FOV_width successfully.
# Completed: Set spatialFootprints for 1 sessions successfully.
# Centroids must be set before ROI images can be created. Creating centroids now.
# Completed: Created centroids.
# Starting: Creating centered ROI images from spatial footprints...
# Completed: Created ROI images.

# %% [markdown]
# # ROInet embedding
#
# This step passes the images of each ROI through the ROInet neural network. The inputs are the images, the output is an array describing the visual properties of each ROI.

# %% [markdown]
# ##### 1. Initialize ROInet
#
# Initialize the ROInet object. The `ROInet_embedder` class will automatically download and load a pretrained ROInet model. If you have a GPU, this step will be much faster.

# %%
DEVICE = roicat.helpers.set_device(use_GPU=True, verbose=True)
dir_temp = "/scratch"

roinet = roicat.ROInet.ROInet_embedder(
    device=DEVICE,  ## Which torch device to use ('cpu', 'cuda', etc.)
    dir_networkFiles=dir_temp,  ## Directory to download the pretrained network to
    download_method='check_local_first',  ## Check to see if a model has already been downloaded to the location (will skip if hash matches)
    download_url='https://osf.io/c8m3b/download',  ## URL of the model
    download_hash='357a8d9b630ec79f3e015d0056a4c2d5',  ## Hash of the model file
    forward_pass_version='head',  ## How the data is passed through the network
    verbose=True,  ## Whether to print updates
)

roinet.generate_dataloader(
    ROI_images=ROI_images, ## Input images of ROIs
    um_per_pixel=um_per_pixel,  ## Resolution of FOV
    pref_plot=False,  ## Whether or not to plot the ROI sizes
    resize_ROI_images=True
);
images = roinet.ROI_images_rs
# Out:
# Using device: cuda:0
# File already exists locally: /scratch/ROInet.zip
# Hash of local file matches provided hash_hex.
# Extracting /scratch/ROInet.zip to /scratch.
# Completed zip extraction.
# Imported model from /scratch/ROInet_classification_20220902/model.py
# Loaded params_model from /scratch/ROInet_classification_20220902/params.json
# /opt/conda/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ConvNeXt_Tiny_Weights.IMAGENET1K_V1`. You can also use `weights=ConvNeXt_Tiny_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Generated network using params_model
# Loaded state_dict into network from /scratch/ROInet_classification_20220902/ConvNext_tiny__1_0_unfrozen__simCLR.pth
# Loaded network onto device cuda:0
# Starting Image Resizer
# Creating dataloader
# Defined image transformations: Sequential(
#   (0): ScaleDynamicRange(scaler_bounds=(0, 1))
#   (1): Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#   (2): TileChannels(dim=0)
# )
# Defined dataset
# Defined dataloader

# %% [markdown]
# ##### 2. Check ROI_images sizes
# In general, you want to see that a neuron fills roughly 25-50% of the area of the image. \
# **Adjust `um_per_pixel` above to rescale image size**

# %%
roicat.visualization.display_toggle_image_stack(images[::20], image_size=(200,200))
# Out:
#     <div>
#         <input type="range" id="imageSlider_f11ed8f01e603cd41b7eaa42a6405163aceac611511f43555cd8c30923d70328" min="0" max="1535" value="0">
#         <img id="displayedImage_f11ed8f01e603cd41b7eaa42a6405163aceac611511f43555cd8c30923d70328" src="data:image/png;base64,..." style="width: 200px; height: 200px;">
#         <span id="imageNumber_f11ed8f01e603cd41b7eaa42a6405163aceac611511f43555cd8c30923d70328">Image 0/1535</span>
#     </div>
#
#     <script>
#         (function() {
#             let base64_images = ['...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...' ...

# %% [markdown]
# ##### 3. Pass data through network
#
# Pass the data through the network. Expect for large datasets (~40,000 ROIs) that this takes around 15 minutes on CPU or 1 minute on GPU.

# %%
roinet.generate_latents()
# Out:
# starting: running data through network
#   0%|          | 0/3839 [00:00<?, ?it/s]
# completed: running data through network
# tensor([[  -0.0000,   -0.0000,  896.1519,  ...,   -0.0000,   -0.0000,
#          1059.1604],
#         [  -0.0000,   -0.0000,   -0.0000,  ...,   -0.0000,   -0.0000,
#           631.0707],
#         [  -0.0000,   -0.0000, 1750.0483,  ...,   -0.0000,   -0.0000,
#          1231.0955],
#         ...,
#         [  -0.0000,   -0.0000,   -0.0000,  ...,   -0.0000,   -0.0000,
#          1399.6885],
#         [  -0.0000,   -0.0000,  541.1902,  ...,   -0.0000,   -0.0000,
#           787.2416],
#         [  -0.0000,   -0.0000,  149.9486,  ...,   -0.0000,   -0.0000,
#          1473.2650]])

# %% [markdown]
# # UMAP embedding
#
# Reduce the dimensionality of the output of ROInet (~100 dims) to 2 dimensions so that we can visualize it. Feel free to use any settings here that do a good job of clustering your data as you see fit.

# %%
model_umap = UMAP(
    n_neighbors=35,
    n_components=2,
    n_epochs=400,
    verbose=True,
    densmap=False,
)
emb = model_umap.fit_transform(roinet.latents)
# Out:
# UMAP(n_epochs=400, n_neighbors=35, verbose=True)
# Thu Jan  8 21:30:08 2026 Construct fuzzy simplicial set
# Thu Jan  8 21:30:08 2026 Finding Nearest Neighbors
# Thu Jan  8 21:30:08 2026 Building RP forest with 14 trees
# Thu Jan  8 21:30:11 2026 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Thu Jan  8 21:30:25 2026 Finished Nearest Neighbor Search
# Thu Jan  8 21:30:27 2026 Construct embedding
# Epochs completed:   0%|            0/400 [00:00]
# 	completed  0  /  400 epochs
# 	completed  40  /  400 epochs
# 	completed  80  /  400 epochs
# 	completed  120  /  400 epochs
# 	completed  160  /  400 epochs
# 	completed  200  /  400 epochs
# 	completed  240  /  400 epochs
# 	completed  280  /  400 epochs
# 	completed  320  /  400 epochs
# 	completed  360  /  400 epochs
# Thu Jan  8 21:30:58 2026 Finished embedding

# %% [markdown]
# # Draw selection

# %% [markdown]
# In order to visualize the kinds of ROIs at each region of the plot, we need to select a subset of points to overlay ROI images onto.

# %%
idx_images_overlay = roicat.visualization.get_spread_out_points(
    emb,
    n_ims=min(emb.shape[0], 2000),  ## Select number of overlayed images here
    dist_im_to_point=0.8,
#     border_frac=0.05,
)

images_overlay = images[idx_images_overlay]

# %% [markdown]
# Now we can use an interactive plot (using the holoviews library) to select our region of the scatterplot to circle.\
# This plot works as follows:
# - Use the **LASSO TOOL** to circle a region on the plot containing the images of ROIs that you'd like to keep/extract/mark.
#     - You can circle multiple times, but only the last one will be saved
# - The saved indices are saved in a temporary file that can be recovered using the `fn_get_indices` function output below. Just call `fn_get_indices()` and it will return a list of the integer indices.
# - If it is difficult to see the images, do the following:
#     - adjust the number of images in the above function (`roicat.visualization.get_spread_out_points`) using the `n_ims` argument
#     - adjust the overlap of the images in the below function (`roicat.visualization.select_region_scatterPlot`) using the `frac_overlap_allowed` argument

# %%
fn_get_indices, layout, path_tempFile = roicat.visualization.select_region_scatterPlot(
    data=emb,
    idx_images_overlay=idx_images_overlay,
    images_overlay=images_overlay[:, 6:30][:,:,6:30],
    size_images_overlay=0.35,
    frac_overlap_allowed=0.4,
    figsize=(1200,1200),
    alpha_points=1.0,
    size_points=10,
    color_points='b',
);
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="eb5ee44e-3ccd-4ad6-8b12-468e11a205a8" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"1245a915-ea89-48cf-a8d3-d2fd0bdfafee":{"version":"3.6.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"3f34da585dce4efdb7ac406f8f79192a","client_comm_id":"32240b5198e94815992d92058be4881c"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind" ...
#   var render_items = [{"docid":"1245a915-ea89-48cf-a8d3-d2fd0bdfafee","roots":{"p1002":"eb5ee44e-3ccd-4ad6-8b12-468e11a205a8"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Overlay
#    .Points.I :Points   [x,y]
#    .RGB.I    :RGB   [x,y]   (R,G,B,A)

# %% [markdown]
# Drop the results into easier to use output variables

# %%
n_sessions = len(ROI_images)
n_roi = [ri.shape[0] for ri in ROI_images]
idx_session_cat = np.concatenate([[ii]*ROI_images[ii].shape[0] for ii in range(n_sessions)])
bool_soma_cat = roicat.helpers.idx2bool(fn_get_indices(), length=len(idx_session_cat))
preds_soma_sessions = roicat.util.JSON_List([[int(l) for l in labels] for labels in roicat.util.labels_to_labelsBySession(bool_soma_cat, n_roi)])

# %%
n_sessions = len(ROI_images)
n_roi = [ri.shape[0] for ri in ROI_images]
idx_session_cat = np.concatenate([[ii]*ROI_images[ii].shape[0] for ii in range(n_sessions)])
bool_dendrite_cat = roicat.helpers.idx2bool(fn_get_indices(), length=len(idx_session_cat))
preds_dendrite_sessions = roicat.util.JSON_List([[int(l) for l in labels] for labels in roicat.util.labels_to_labelsBySession(bool_dendrite_cat, n_roi)])

# %%
run_data = {
    'ROI_images':[di.ROI_images[0] for di in data_importers], ## Input images of ROIs
    'um_per_pixel':[ di.um_per_pixel[0] for di in data_importers],  ## Resolution of FOV
    "roinet": roinet.__dict__,
    "umap_embedding": emb,
    "dendrite_preds": preds_dendrite_sessions,
    "soma_preds": preds_soma_sessions
}

# %% [markdown]
# # Save results
#
# The results file can be opened using any of the following methods:
# 1. `roicat.helpers.pickle_load(path)`
# 2. `np.load(path)`
# 3.
# ```
#     import pickle
#     with open(path_save, mode='rb') as f:
#         test = pickle.load(f)
#   ```

# %%
## Define the directory to save the results to
dir_save = '/results/'

paths_save = {
    'soma_preds': str(Path(dir_save) / f'soma_classification_drawn.preds.json'),
    'dendrite_preds': str(Path(dir_save) / f'dendrite_classification_drawn.preds.json'),
    'run_data': str(Path(dir_save) / f'classification_drawn.run_data.richfile'),
}

roicat.helpers.json_save(obj=run_data["soma_preds"], filepath=paths_save['soma_preds'])
roicat.helpers.json_save(obj=run_data["dendrite_preds"], filepath=paths_save['dendrite_preds'])
roicat.util.RichFile_ROICaT(path=paths_save['run_data']).save(run_data, overwrite=True)
# Out:
# Path: /results/classification_drawn.run_data.richfile (dict)
# ├── 'ROI_images':   (list)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |    ├──   (numpy_array)
# |
# ├── 'um_per_pixel':   (list)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |    ├──   (float)
# |
# ├── 'roinet':   (dict)
# |    ├── '_system_info':   (dict)
# |    |    ├── 'datetime':   (str)
# |    |    ├── 'roicat':   (dict)
# |    |    |    ├── 'version':   (str)
# |    |    |    ├── 'date_installed':   (str)
# |    |    |
# |    |    ├── 'operating_system':   (dict)
# |    |    |    ├── 'libc_ver':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'win32_is_iot':   (bool)
# |    |    |    ├── 'win32_edition':   (None)
# |    |    |    ├── 'win32_ver':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'mac_ver':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (list)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'java_ver':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (list)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |
# |    |    |    |    ├──   (list)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |
# |    |    |    |
# |    |    |    ├── 'system_alias':   (None)
# |    |    |    ├── 'architecture':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'uname_result':   (None)
# |    |    |    ├── 'uname':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'system':   (str)
# |    |    |    ├── 'node':   (str)
# |    |    |    ├── 'release':   (str)
# |    |    |    ├── 'version':   (str)
# |    |    |    ├── 'machine':   (str)
# |    |    |    ├── 'processor':   (str)
# |    |    |    ├── 'python_implementation':   (str)
# |    |    |    ├── 'python_version':   (str)
# |    |    |    ├── 'python_version_tuple':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'python_branch':   (str)
# |    |    |    ├── 'python_revision':   (str)
# |    |    |    ├── 'python_build':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'python_compiler':   (str)
# |    |    |    ├── 'platform':   (str)
# |    |    |    ├── 'freedesktop_os_release':   (dict)
# |    |    |    |    ├── 'NAME':   (str)
# |    |    |    |    ├── 'ID':   (str)
# |    |    |    |    ├── 'PRETTY_NAME':   (str)
# |    |    |    |    ├── 'VERSION_ID':   (str)
# |    |    |    |    ├── 'VERSION':   (str)
# |    |    |    |    ├── 'VERSION_CODENAME':   (str)
# |    |    |    |    ├── 'ID_LIKE':   (str)
# |    |    |    |    ├── 'HOME_URL':   (str)
# |    |    |    |    ├── 'SUPPORT_URL':   (str)
# |    |    |    |    ├── 'BUG_REPORT_URL':   (str)
# |    |    |    |    ├── 'PRIVACY_POLICY_URL':   (str)
# |    |    |    |    ├── 'UBUNTU_CODENAME':   (str)
# |    |    |    |
# |    |    |
# |    |    ├── 'cpu_info':   (dict)
# |    |    |    ├── 'n_cores':   (int)
# |    |    |    ├── 'brand':   (str)
# |    |    |
# |    |    ├── 'user':   (str)
# |    |    ├── 'ram':   (list)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (float)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |
# |    |    ├── 'gpu_info':   (dict)
# |    |    |    ├── '0':   (dict)
# |    |    |    |    ├── 'id':   (int)
# |    |    |    |    ├── 'uuid':   (str)
# |    |    |    |    ├── 'load':   (float)
# |    |    |    |    ├── 'memoryUtil':   (float)
# |    |    |    |    ├── 'memoryTotal':   (float)
# |    |    |    |    ├── 'memoryUsed':   (float)
# |    |    |    |    ├── 'memoryFree':   (float)
# |    |    |    |    ├── 'driver':   (str)
# |    |    |    |    ├── 'name':   (str)
# |    |    |    |    ├── 'serial':   (str)
# |    |    |    |    ├── 'display_mode':   (str)
# |    |    |    |    ├── 'display_active':   (str)
# |    |    |    |    ├── 'temperature':   (float)
# |    |    |    |
# |    |    |
# |    |    ├── 'conda_env':   (str)
# |    |    ├── 'python':   (str)
# |    |    ├── 'gcc':   (str)
# |    |    ├── 'torch':   (str)
# |    |    ├── 'cuda':   (str)
# |    |    ├── 'cudnn':   (int)
# |    |    ├── 'torch_devices':   (list)
# |    |    |    ├──   (str)
# |    |    |
# |    |    ├── 'pkgs':   (dict)
# |    |    |    ├── 'brotli':   (str)
# |    |    |    ├── 'pysocks':   (str)
# |    |    |    ├── 'archspec':   (str)
# |    |    |    ├── 'boltons':   (str)
# |    |    |    ├── 'cffi':   (str)
# |    |    |    ├── 'charset-normalizer':   (str)
# |    |    |    ├── 'colorama':   (str)
# |    |    |    ├── 'conda':   (str)
# |    |    |    ├── 'conda-libmamba-solver':   (str)
# |    |    |    ├── 'conda-package-handling':   (str)
# |    |    |    ├── 'conda_package_streaming':   (str)
# |    |    |    ├── 'distro':   (str)
# |    |    |    ├── 'frozendict':   (str)
# |    |    |    ├── 'h2':   (str)
# |    |    |    ├── 'hpack':   (str)
# |    |    |    ├── 'hyperframe':   (str)
# |    |    |    ├── 'idna':   (str)
# |    |    |    ├── 'jsonpatch':   (str)
# |    |    |    ├── 'jsonpointer':   (str)
# |    |    |    ├── 'libmambapy':   (str)
# |    |    |    ├── 'mamba':   (str)
# |    |    |    ├── 'menuinst':   (str)
# |    |    |    ├── 'packaging':   (str)
# |    |    |    ├── 'pip':   (str)
# |    |    |    ├── 'platformdirs':   (str)
# |    |    |    ├── 'pluggy':   (str)
# |    |    |    ├── 'pycosat':   (str)
# |    |    |    ├── 'pycparser':   (str)
# |    |    |    ├── 'requests':   (str)
# |    |    |    ├── 'ruamel.yaml':   (str)
# |    |    |    ├── 'ruamel.yaml.clib':   (str)
# |    |    |    ├── 'setuptools':   (str)
# |    |    |    ├── 'truststore':   (str)
# |    |    |    ├── 'urllib3':   (str)
# |    |    |    ├── 'wheel':   (str)
# |    |    |    ├── 'zstandard':   (str)
# |    |    |    ├── 'asciitree':   (str)
# |    |    |    ├── 'dill':   (str)
# |    |    |    ├── 'fasteners':   (str)
# |    |    |    ├── 'hdmf':   (str)
# |    |    |    ├── 'lazy-ops':   (str)
# |    |    |    ├── 'numcodecs':   (str)
# |    |    |    ├── 'pynwb':   (str)
# |    |    |    ├── 'roiextractors':   (str)
# |    |    |    ├── 'zarr':   (str)
# |    |    |    ├── 'gputil':   (str)
# |    |    |    ├── 'gitpython':   (str)
# |    |    |    ├── 'mako':   (str)
# |    |    |    ├── 'markdown':   (str)
# |    |    |    ├── 'pint':   (str)
# |    |    |    ├── 'qtpy':   (str)
# |    |    |    ├── 'sqlalchemy':   (str)
# |    |    |    ├── 'send2trash':   (str)
# |    |    |    ├── 'alembic':   (str)
# |    |    |    ├── 'anyio':   (str)
# |    |    |    ├── 'appdirs':   (str)
# |    |    |    ├── 'argon2-cffi':   (str)
# |    |    |    ├── 'argon2-cffi-bindings':   (str)
# |    |    |    ├── 'arrow':   (str)
# |    |    |    ├── 'asttokens':   (str)
# |    |    |    ├── 'async-lru':   (str)
# |    |    |    ├── 'attrs':   (str)
# |    |    |    ├── 'babel':   (str)
# |    |    |    ├── 'beautifulsoup4':   (str)
# |    |    |    ├── 'bleach':   (str)
# |    |    |    ├── 'bokeh':   (str)
# |    |    |    ├── 'click':   (str)
# |    |    |    ├── 'colorcet':   (str)
# |    |    |    ├── 'coloredlogs':   (str)
# |    |    |    ├── 'colorlog':   (str)
# |    |    |    ├── 'comm':   (str)
# |    |    |    ├── 'configparser':   (str)
# |    |    |    ├── 'contourpy':   (str)
# |    |    |    ├── 'cycler':   (str)
# |    |    |    ├── 'debugpy':   (str)
# |    |    |    ├── 'decorator':   (str)
# |    |    |    ├── 'defusedxml':   (str)
# |    |    |    ├── 'docker-pycreds':   (str)
# |    |    |    ├── 'einops':   (str)
# |    |    |    ├── 'executing':   (str)
# |    |    |    ├── 'fastjsonschema':   (str)
# |    |    |    ├── 'flatbuffers':   (str)
# |    |    |    ├── 'flexcache':   (str)
# |    |    |    ├── 'flexparser':   (str)
# |    |    |    ├── 'fonttools':   (str)
# |    |    |    ├── 'fqdn':   (str)
# |    |    |    ├── 'fsspec':   (str)
# |    |    |    ├── 'gitdb':   (str)
# |    |    |    ├── 'greenlet':   (str)
# |    |    |    ├── 'h11':   (str)
# |    |    |    ├── 'h5py':   (str)
# |    |    |    ├── 'hdbscan':   (str)
# |    |    |    ├── 'holoviews':   (str)
# |    |    |    ├── 'httpcore':   (str)
# |    |    |    ├── 'httpx':   (str)
# |    |    |    ├── 'huggingface-hub':   (str)
# |    |    |    ├── 'humanfriendly':   (str)
# |    |    |    ├── 'hypothesis':   (str)
# |    |    |    ├── 'imageio':   (str)
# |    |    |    ├── 'iniconfig':   (str)
# |    |    |    ├── 'ipykernel':   (str)
# |    |    |    ├── 'ipython':   (str)
# |    |    |    ├── 'ipywidgets':   (str)
# |    |    |    ├── 'isoduration':   (str)
# |    |    |    ├── 'jedi':   (str)
# |    |    |    ├── 'joblib':   (str)
# |    |    |    ├── 'json5':   (str)
# |    |    |    ├── 'jsonschema':   (str)
# |    |    |    ├── 'jsonschema-specifications':   (str)
# |    |    |    ├── 'jupyter':   (str)
# |    |    |    ├── 'jupyter_bokeh':   (str)
# |    |    |    ├── 'jupyter_client':   (str)
# |    |    |    ├── 'jupyter-console':   (str)
# |    |    |    ├── 'jupyter_core':   (str)
# |    |    |    ├── 'jupyter-events':   (str)
# |    |    |    ├── 'jupyter-lsp':   (str)
# |    |    |    ├── 'jupyter_server':   (str)
# |    |    |    ├── 'jupyter_server_terminals':   (str)
# |    |    |    ├── 'jupyterlab':   (str)
# |    |    |    ├── 'jupyterlab_pygments':   (str)
# |    |    |    ├── 'jupyterlab_server':   (str)
# |    |    |    ├── 'jupyterlab_widgets':   (str)
# |    |    |    ├── 'kiwisolver':   (str)
# |    |    |    ├── 'kornia':   (str)
# |    |    |    ├── 'kornia_rs':   (str)
# |    |    |    ├── 'kymatio':   (str)
# |    |    |    ├── 'lazy_loader':   (str)
# |    |    |    ├── 'linkify-it-py':   (str)
# |    |    |    ├── 'llvmlite':   (str)
# |    |    |    ├── 'loguru':   (str)
# |    |    |    ├── 'markdown-it-py':   (str)
# |    |    |    ├── 'mat73':   (str)
# |    |    |    ├── 'matplotlib':   (str)
# |    |    |    ├── 'matplotlib-inline':   (str)
# |    |    |    ├── 'mdit-py-plugins':   (str)
# |    |    |    ├── 'mdurl':   (str)
# |    |    |    ├── 'mistune':   (str)
# |    |    |    ├── 'natsort':   (str)
# |    |    |    ├── 'nbclient':   (str)
# |    |    |    ├── 'nbconvert':   (str)
# |    |    |    ├── 'nbformat':   (str)
# |    |    |    ├── 'nest-asyncio':   (str)
# |    |    |    ├── 'notebook':   (str)
# |    |    |    ├── 'notebook_shim':   (str)
# |    |    |    ├── 'numba':   (str)
# |    |    |    ├── 'numpy':   (str)
# |    |    |    ├── 'nvidia-cublas-cu12':   (str)
# |    |    |    ├── 'nvidia-cuda-cupti-cu12':   (str)
# |    |    |    ├── 'nvidia-cuda-nvrtc-cu12':   (str)
# |    |    |    ├── 'nvidia-cuda-runtime-cu12':   (str)
# |    |    |    ├── 'nvidia-cudnn-cu12':   (str)
# |    |    |    ├── 'nvidia-cufft-cu12':   (str)
# |    |    |    ├── 'nvidia-curand-cu12':   (str)
# |    |    |    ├── 'nvidia-cusolver-cu12':   (str)
# |    |    |    ├── 'nvidia-cusparse-cu12':   (str)
# |    |    |    ├── 'nvidia-nccl-cu12':   (str)
# |    |    |    ├── 'nvidia-nvjitlink-cu12':   (str)
# |    |    |    ├── 'nvidia-nvtx-cu12':   (str)
# |    |    |    ├── 'onnx':   (str)
# |    |    |    ├── 'onnx2torch':   (str)
# |    |    |    ├── 'onnxconverter-common':   (str)
# |    |    |    ├── 'onnxruntime':   (str)
# |    |    |    ├── 'opencv-contrib-python-headless':   (str)
# |    |    |    ├── 'optuna':   (str)
# |    |    |    ├── 'outcome':   (str)
# |    |    |    ├── 'overrides':   (str)
# |    |    |    ├── 'pandas':   (str)
# |    |    |    ├── 'pandocfilters':   (str)
# |    |    |    ├── 'panel':   (str)
# |    |    |    ├── 'param':   (str)
# |    |    |    ├── 'parso':   (str)
# |    |    |    ├── 'pexpect':   (str)
# |    |    |    ├── 'pillow':   (str)
# |    |    |    ├── 'plotly':   (str)
# |    |    |    ├── 'poselib':   (str)
# |    |    |    ├── 'prometheus_client':   (str)
# |    |    |    ├── 'prompt_toolkit':   (str)
# |    |    |    ├── 'protobuf':   (str)
# |    |    |    ├── 'psutil':   (str)
# |    |    |    ├── 'ptyprocess':   (str)
# |    |    |    ├── 'pure_eval':   (str)
# |    |    |    ├── 'py-cpuinfo':   (str)
# |    |    |    ├── 'pygments':   (str)
# |    |    |    ├── 'pynndescent':   (str)
# |    |    |    ├── 'pyparsing':   (str)
# |    |    |    ├── 'pytest':   (str)
# |    |    |    ├── 'python-dateutil':   (str)
# |    |    |    ├── 'python-json-logger':   (str)
# |    |    |    ├── 'pytz':   (str)
# |    |    |    ├── 'pyviz_comms':   (str)
# |    |    |    ├── 'pyzmq':   (str)
# |    |    |    ├── 'qtconsole':   (str)
# |    |    |    ├── 'referencing':   (str)
# |    |    |    ├── 'rfc3339-validator':   (str)
# |    |    |    ├── 'rfc3986-validator':   (str)
# |    |    |    ├── 'richfile':   (str)
# |    |    |    ├── 'roicat':   (str)
# |    |    |    ├── 'romatch_roicat':   (str)
# |    |    |    ├── 'rpds-py':   (str)
# |    |    |    ├── 'safetensors':   (str)
# |    |    |    ├── 'scikit-image':   (str)
# |    |    |    ├── 'scikit-learn':   (str)
# |    |    |    ├── 'scipy':   (str)
# |    |    |    ├── 'seaborn':   (str)
# |    |    |    ├── 'selenium':   (str)
# |    |    |    ├── 'sentry-sdk':   (str)
# |    |    |    ├── 'setproctitle':   (str)
# |    |    |    ├── 'six':   (str)
# |    |    |    ├── 'skl2onnx':   (str)
# |    |    |    ├── 'smmap':   (str)
# |    |    |    ├── 'sniffio':   (str)
# |    |    |    ├── 'sortedcontainers':   (str)
# |    |    |    ├── 'soupsieve':   (str)
# |    |    |    ├── 'sparse':   (str)
# |    |    |    ├── 'stack-data':   (str)
# |    |    |    ├── 'sympy':   (str)
# |    |    |    ├── 'tenacity':   (str)
# |    |    |    ├── 'terminado':   (str)
# |    |    |    ├── 'threadpoolctl':   (str)
# |    |    |    ├── 'tifffile':   (str)
# |    |    |    ├── 'timm':   (str)
# |    |    |    ├── 'tinycss2':   (str)
# |    |    |    ├── 'torch':   (str)
# |    |    |    ├── 'torchaudio':   (str)
# |    |    |    ├── 'torchvision':   (str)
# |    |    |    ├── 'tornado':   (str)
# |    |    |    ├── 'tqdm':   (str)
# |    |    |    ├── 'traitlets':   (str)
# |    |    |    ├── 'trio':   (str)
# |    |    |    ├── 'trio-websocket':   (str)
# |    |    |    ├── 'triton':   (str)
# |    |    |    ├── 'types-python-dateutil':   (str)
# |    |    |    ├── 'tzdata':   (str)
# |    |    |    ├── 'uc-micro-py':   (str)
# |    |    |    ├── 'umap-learn':   (str)
# |    |    |    ├── 'uri-template':   (str)
# |    |    |    ├── 'wandb':   (str)
# |    |    |    ├── 'wcwidth':   (str)
# |    |    |    ├── 'webcolors':   (str)
# |    |    |    ├── 'webencodings':   (str)
# |    |    |    ├── 'websocket-client':   (str)
# |    |    |    ├── 'widgetsnbextension':   (str)
# |    |    |    ├── 'wsproto':   (str)
# |    |    |    ├── 'xxhash':   (str)
# |    |    |    ├── 'xyzservices':   (str)
# |    |    |    ├── 'markupsafe':   (str)
# |    |    |    ├── 'pyyaml':   (str)
# |    |    |    ├── 'certifi':   (str)
# |    |    |    ├── 'filelock':   (str)
# |    |    |    ├── 'gmpy2':   (str)
# |    |    |    ├── 'jinja2':   (str)
# |    |    |    ├── 'mpmath':   (str)
# |    |    |    ├── 'networkx':   (str)
# |    |    |    ├── 'typing_extensions':   (str)
# |    |    |    ├── 'autocommand':   (str)
# |    |    |    ├── 'backports.tarfile':   (str)
# |    |    |    ├── 'importlib_metadata':   (str)
# |    |    |    ├── 'importlib_resources':   (str)
# |    |    |    ├── 'inflect':   (str)
# |    |    |    ├── 'jaraco.context':   (str)
# |    |    |    ├── 'jaraco.functools':   (str)
# |    |    |    ├── 'jaraco.text':   (str)
# |    |    |    ├── 'more-itertools':   (str)
# |    |    |    ├── 'ordered-set':   (str)
# |    |    |    ├── 'tomli':   (str)
# |    |    |    ├── 'typeguard':   (str)
# |    |    |    ├── 'zipp':   (str)
# |    |    |
# |    |
# |    ├── 'params':   (dict)
# |    |    ├── '__init__':   (dict)
# |    |    |    ├── 'dir_networkFiles':   (str)
# |    |    |    ├── 'device':   (str)
# |    |    |    ├── 'download_method':   (str)
# |    |    |    ├── 'download_url':   (str)
# |    |    |    ├── 'download_hash':   (str)
# |    |    |    ├── 'names_networkFiles':   (None)
# |    |    |    ├── 'forward_pass_version':   (str)
# |    |    |    ├── 'verbose':   (bool)
# |    |    |
# |    |    ├── 'generate_dataloader':   (dict)
# |    |    |    ├── 'um_per_pixel':   (list)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |
# |    |    |    ├── 'nan_to_num':   (bool)
# |    |    |    ├── 'nan_to_num_val':   (float)
# |    |    |    ├── 'pref_plot':   (bool)
# |    |    |    ├── 'batchSize_dataloader':   (int)
# |    |    |    ├── 'pinMemory_dataloader':   (bool)
# |    |    |    ├── 'numWorkers_dataloader':   (int)
# |    |    |    ├── 'persistentWorkers_dataloader':   (bool)
# |    |    |    ├── 'prefetchFactor_dataloader':   (int)
# |    |    |    ├── 'img_size_out':   (tuple)
# |    |    |    |    ├──   (int)
# |    |    |    |    ├──   (int)
# |    |    |    |
# |    |    |    ├── 'jit_script_transforms':   (bool)
# |    |    |
# |    |
# |    ├── '_device':   (str)
# |    ├── '_verbose':   (bool)
# |    ├── '_dir_networkFiles':   (str)
# |    ├── '_download_url':   (str)
# |    ├── '_download_path_save':   (str)
# |    ├── 'params_model':   (dict)
# |    |    ├── 'pref_log_all_steps':   (bool)
# |    |    ├── 'paths':   (dict)
# |    |    |    ├── 'dir_github':   (str)
# |    |    |    ├── 'fileName_save_model':   (str)
# |    |    |    ├── 'path_data_training':   (str)
# |    |    |
# |    |    ├── 'prefs':   (dict)
# |    |    |    ├── 'saveModelIteratively':   (bool)
# |    |    |    ├── 'saveLogs':   (bool)
# |    |    |
# |    |    ├── 'useGPU_training':   (bool)
# |    |    ├── 'useGPU_dataloader':   (bool)
# |    |    ├── 'dataloader_kwargs':   (dict)
# |    |    |    ├── 'batch_size':   (int)
# |    |    |    ├── 'shuffle':   (bool)
# |    |    |    ├── 'drop_last':   (bool)
# |    |    |    ├── 'pin_memory':   (bool)
# |    |    |    ├── 'num_workers':   (int)
# |    |    |    ├── 'persistent_workers':   (bool)
# |    |    |    ├── 'prefetch_factor':   (int)
# |    |    |
# |    |    ├── 'inner_batch_size':   (int)
# |    |    ├── 'torchvision_model':   (str)
# |    |    ├── 'pre_head_fc_sizes':   (list)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |
# |    |    ├── 'post_head_fc_sizes':   (list)
# |    |    |    ├──   (int)
# |    |    |
# |    |    ├── 'block_to_unfreeze':   (str)
# |    |    ├── 'n_block_toInclude':   (int)
# |    |    ├── 'head_nonlinearity':   (str)
# |    |    ├── 'lr':   (float)
# |    |    ├── 'penalty_orthogonality':   (float)
# |    |    ├── 'weight_decay':   (float)
# |    |    ├── 'gamma':   (float)
# |    |    ├── 'n_epochs':   (int)
# |    |    ├── 'temperature':   (float)
# |    |    ├── 'l2_alpha':   (float)
# |    |    ├── 'augmentation':   (dict)
# |    |    |    ├── 'Scale_image_sum':   (dict)
# |    |    |    |    ├── 'sum_val':   (int)
# |    |    |    |    ├── 'epsilon':   (float)
# |    |    |    |    ├── 'min_sub':   (bool)
# |    |    |    |
# |    |    |    ├── 'AddPoissonNoise':   (dict)
# |    |    |    |    ├── 'scaler_bounds':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'prob':   (float)
# |    |    |    |    ├── 'base':   (int)
# |    |    |    |    ├── 'scaling':   (str)
# |    |    |    |
# |    |    |    ├── 'Horizontal_stripe_scale':   (dict)
# |    |    |    |    ├── 'alpha_min_max':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'im_size':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'prob':   (float)
# |    |    |    |
# |    |    |    ├── 'Horizontal_stripe_shift':   (dict)
# |    |    |    |    ├── 'alpha_min_max':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'im_size':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'prob':   (float)
# |    |    |    |
# |    |    |    ├── 'RandomHorizontalFlip':   (dict)
# |    |    |    |    ├── 'p':   (float)
# |    |    |    |
# |    |    |    ├── 'RandomAffine':   (dict)
# |    |    |    |    ├── 'degrees':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'translate':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'scale':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'shear':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'interpolation':   (str)
# |    |    |    |    ├── 'fill':   (int)
# |    |    |    |    ├── 'fillcolor':   (None)
# |    |    |    |    ├── 'resample':   (None)
# |    |    |    |
# |    |    |    ├── 'AddGaussianNoise':   (dict)
# |    |    |    |    ├── 'mean':   (int)
# |    |    |    |    ├── 'std':   (float)
# |    |    |    |    ├── 'prob':   (float)
# |    |    |    |
# |    |    |    ├── 'ScaleDynamicRange':   (dict)
# |    |    |    |    ├── 'scaler_bounds':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'epsilon':   (float)
# |    |    |    |
# |    |    |    ├── 'WarpPoints':   (dict)
# |    |    |    |    ├── 'r':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'cx':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'cy':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'dx':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'dy':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'n_warps':   (int)
# |    |    |    |    ├── 'prob':   (float)
# |    |    |    |    ├── 'img_size_in':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'img_size_out':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |
# |    |    |    ├── 'TileChannels':   (dict)
# |    |    |    |    ├── 'dim':   (int)
# |    |    |    |    ├── 'n_channels':   (int)
# |    |    |    |
# |    |    |
# |    |
# |    ├── 'net':   (torch_module)
# |    ├── 'ROI_images_rs':   (numpy_array)
# |    ├── 'transforms':   (torch_sequence)
# |    ├── 'dataset':   (torch_dataset)
# |    ├── 'dataloader':   (torch_dataloader)
# |    ├── 'latents':   (torch_tensor)
# |
# ├── 'umap_embedding':   (numpy_array)
# ├── 'dendrite_preds':   (json_list)
# ├── 'soma_preds':   (json_list)
# RichFile(path=/results/classification_drawn.run_data.richfile, check=True, params_load={}, params_save={})

# %% [markdown]
# # Thank you
# If you encountered any difficulties, please let us know at the issues page: https://github.com/RichieHakim/ROICaT/issues
