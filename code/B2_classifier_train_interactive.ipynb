# %% [markdown]
# # Intro

# %% [markdown]
# Welcome to the classifier training notebook!
#
# To run this notebook, you must first have prepared images and labels. This can be done using the `labeling_interactive.ipynb` notebook, or can be provided manually.
#
# The notebook proceeds as follows:
# 1. **Import** libraries
# 2. Define **paths** to data
# 3. **Train** a classifier
# 4. **Save** results

# %% [markdown]
# # Imports

# %%
# widen jupyter notebook window
from IPython.display import display, HTML
display(HTML("<style>.container {width:95% !important; }</style>"))
# Out:
# <style>.container {width:95% !important; }</style>

# %%
from pathlib import Path
import tempfile
import functools

import numpy as np
import sklearn
import pandas as pd

# %%
import roicat

# %% [markdown]
# # Data Importing

# %% [markdown]
# ## Option 1: Use Data Results from Labeling Interactive Outputs

# %% [markdown]
# ##### 1. Specify filepath

# %%
filepath_labeling_results = r'/results/dendrite_classification_drawn.run_data.richfile'
labelingInteractive = roicat.util.RichFile_ROICaT(path=filepath_labeling_results).load()

# %% [markdown]
# ##### 2. Import data
#
# Be sure to specify a `um_per_pixel`

# %%
data = roicat.data_importing.Data_roicat();
data.set_ROI_images(
    ROI_images=labelingInteractive['ROI_images'],
    um_per_pixel=labelingInteractive['um_per_pixel']
);
data.set_class_labels(
    labelingInteractive['dendrite_preds'],
);

data.check_completeness()
# Out:
# Starting: Importing ROI images
# Completed: Imported 130 sessions. Each session has [4949, 309, 229, 311, 147, 418, 395, 251, 254, 221, 200, 105, 110, 68, 85, 71, 77, 74, 106, 50, 107, 254, 189, 385, 291, 401, 332, 64, 86, 75, 67, 75, 108, 56, 109, 194, 227, 403, 317, 642, 410, 434, 85, 90, 81, 92, 87, 114, 56, 114, 920, 76, 77, 68, 72, 69, 100, 63, 115, 199, 266, 69, 227, 244, 371, 275, 79, 91, 72, 78, 88, 104, 68, 99, 352, 265, 333, 198, 86, 72, 77, 70, 82, 98, 69, 90, 996, 85, 76, 82, 62, 95, 112, 61, 99, 1008, 241, 265, 73, 81, 70, 74, 73, 108, 56, 96, 248, 217, 74, 75, 67, 72, 70, 95, 47, 101, 85, 71, 448, 123, 123, 593, 85, 70, 77, 62, 83, 102, 68, 84] ROIs. Total number of ROIs is 27010. The um_per_pixel is [1.0416666666666667, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 1.0416666666666667, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 1.0416666666666667, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 1.0416666666666667, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 1.0416666666666667, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 1.0416666666666667, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 1.0416666666666667, 1.0416666666666667, 1.0416666666666667, 0.78, 0.78, 1.0416666666666667, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78, 0.78] um per pixel.
# Starting: Importing class labels
# Labels and ROI Images match in shapes: Class labels and ROI images have the same number of sessions and the same number of ROIs in each session.
# Completed: Imported labels for 130 sessions. Each session has [4949, 309, 229, 311, 147, 418, 395, 251, 254, 221, 200, 105, 110, 68, 85, 71, 77, 74, 106, 50, 107, 254, 189, 385, 291, 401, 332, 64, 86, 75, 67, 75, 108, 56, 109, 194, 227, 403, 317, 642, 410, 434, 85, 90, 81, 92, 87, 114, 56, 114, 920, 76, 77, 68, 72, 69, 100, 63, 115, 199, 266, 69, 227, 244, 371, 275, 79, 91, 72, 78, 88, 104, 68, 99, 352, 265, 333, 198, 86, 72, 77, 70, 82, 98, 69, 90, 996, 85, 76, 82, 62, 95, 112, 61, 99, 1008, 241, 265, 73, 81, 70, 74, 73, 108, 56, 96, 248, 217, 74, 75, 67, 72, 70, 95, 47, 101, 85, 71, 448, 123, 123, 593, 85, 70, 77, 62, 83, 102, 68, 84] class labels. Total number of class labels is 27010.
# RH WARNING: Tracking incomplete because the following attributes are missing: ['spatialFootprints', 'FOV_images']
# Labels and ROI Images match in shapes: Class labels and ROI images have the same number of sessions and the same number of ROIs in each session.
# Cannot check validity of spatialFootprints and FOV_images because one or both do not exist as attributes.
# Data_roicat object completeness: {'classification_inference': True, 'classification_training': True, 'tracking': False}
# {'classification_inference': True,
#  'classification_training': True,
#  'tracking': False}

# %% [markdown]
# Notice that `.check_completeness()` shows that `classification_training` is `True`

# %% [markdown]
# # ROInet embedding
#
# This step passes the images of each ROI through the ROInet neural network. The inputs are the images, the output is an array describing the visual properties of each ROI.

# %% [markdown]
# ##### 1. Initialize ROInet
#
# Initialize the ROInet object. The `ROInet_embedder` class will automatically download and load a pretrained ROInet model. If you have a GPU, this step will be much faster.

# %%
DEVICE = roicat.helpers.set_device(use_GPU=True, verbose=True)
dir_temp = "/scratch/"

roinet = roicat.ROInet.ROInet_embedder(
    device=DEVICE,  ## Which torch device to use ('cpu', 'cuda', etc.)
    dir_networkFiles=dir_temp,  ## Directory to download the pretrained network to
    download_method='check_local_first',  ## Check to see if a model has already been downloaded to the location (will skip if hash matches)
    download_url='https://osf.io/c8m3b/download',  ## URL of the model
    download_hash='357a8d9b630ec79f3e015d0056a4c2d5',  ## Hash of the model file
    forward_pass_version='head',  ## How the data is passed through the network
    verbose=True,  ## Whether to print updates
)

roinet.generate_dataloader(
    ROI_images=data.ROI_images,  ## Input images of ROIs
    um_per_pixel=data.um_per_pixel,  ## Resolution of FOV
    pref_plot=False,  ## Whether or not to plot the ROI sizes
);
# Out:
# Using device: cuda:0
# File already exists locally: /scratch/ROInet.zip
# Hash of local file matches provided hash_hex.
# Extracting /scratch/ROInet.zip to /scratch.
# Completed zip extraction.
# Imported model from /scratch/ROInet_classification_20220902/model.py
# Loaded params_model from /scratch/ROInet_classification_20220902/params.json
# /opt/conda/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ConvNeXt_Tiny_Weights.IMAGENET1K_V1`. You can also use `weights=ConvNeXt_Tiny_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Generated network using params_model
# Loaded state_dict into network from /scratch/ROInet_classification_20220902/ConvNext_tiny__1_0_unfrozen__simCLR.pth
# Loaded network onto device cuda:0
# Starting Image Resizer
# Creating dataloader
# Defined image transformations: Sequential(
#   (0): ScaleDynamicRange(scaler_bounds=(0, 1))
#   (1): Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#   (2): TileChannels(dim=0)
# )
# Defined dataset
# Defined dataloader

# %% [markdown]
# ##### 2. Check ROI_images sizes
# In general, you want to see that a neuron fills roughly 25-50% of the area of the image. \
# **Adjust `um_per_pixel` above to rescale image size**

# %%
roicat.visualization.display_toggle_image_stack(roinet.ROI_images_rs[:1000], image_size=(200,200))
# Out:
#     <div>
#         <input type="range" id="imageSlider_278dbc24538e84c7e8066e0bc089fc6e729711614ff4a09a18b7379fb5d4b3c3" min="0" max="999" value="0">
#         <img id="displayedImage_278dbc24538e84c7e8066e0bc089fc6e729711614ff4a09a18b7379fb5d4b3c3" src="data:image/png;base64,..." style="width: 200px; height: 200px;">
#         <span id="imageNumber_278dbc24538e84c7e8066e0bc089fc6e729711614ff4a09a18b7379fb5d4b3c3">Image 0/999</span>
#     </div>
#
#     <script>
#         (function() {
#             let base64_images = ['...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '', '...', '...', '...', '...', '...', '...', '...', '...', '...', '', '...', '...', '...', ' ...

# %% [markdown]
# ##### 3. Pass data through network
#
# Pass the data through the network. Expect for large datasets (~40,000 ROIs) that this takes around 15 minutes on CPU or 1 minute on GPU.

# %%
roinet.generate_latents()
# Out:
# starting: running data through network
#   0%|          | 0/3377 [00:00<?, ?it/s]
# completed: running data through network
# tensor([[  -0.0000,   -0.0000, 5466.2925,  ...,   -0.0000,   -0.0000,
#          1419.4205],
#         [  -0.0000,   -0.0000,   -0.0000,  ..., 1532.3263, 3100.0474,
#           894.5261],
#         [  -0.0000,   -0.0000, 3737.6550,  ...,   -0.0000,   -0.0000,
#          1908.5192],
#         ...,
#         [  -0.0000,   -0.0000,   -0.0000,  ...,   -0.0000,   -0.0000,
#          1096.4626],
#         [  -0.0000,   -0.0000,   -0.0000,  ...,   -0.0000,   37.2594,
#           990.8394],
#         [  -0.0000,   -0.0000,   -0.0000,  ...,   -0.0000,   -0.0000,
#           798.3900]])

# %% [markdown]
# # Train / Validation / Test Split Data, Hyperparameter Tune on Validation Set, and Fit Model

# %% [markdown]
# Prepare input data

# %%
X = np.array(roinet.latents).astype(np.float32)
y = np.concatenate(data.class_labels_index).astype(np.int64)

# %% [markdown]
# ##### Initialize the **AutoClassifier**.
#
# This class is meant to be easy to use, but advanced users will find all the parameters they might want to play with available as arguments. Feel free to play with some of them by looking through the detailed [**DOCUMENTATION**](https://roicat.readthedocs.io/en/latest/roicat.html#roicat.classification.classifier.Auto_LogisticRegression) on this class. Here's a brief tutorial:
# - This class performs classification by fitting a Logistic Regression model
# - There is one critical parameter in this model: ``'C'``. Lowering 'C' means more regularization.
# - This class will **automatically tune** any parameter that is specified in the `params_LogisticRegression` argument as a list of values. See the sklearn documentation on [LogisticRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html) for the full list of arguments that can be specified in ``params_LogisticRegression``.
#     - Examples:
#     ```
#     ## Initialize with NO TUNING. All parameters are fixed.
#     autoclassifier = Auto_LogisticRegression(
#         X,
#         y,
#         params_LogisticRegression={
#             'C': 1e-14,
#             'penalty': 'l2',
#             'solver': 'lbfgs',
#         },
#     )
#
#     ## Initialize with TUNING 'C', 'penalty', and 'l1_ratio'. 'solver' is fixed.
#     autoclassifier = Auto_LogisticRegression(
#         X,
#         y,
#         params_LogisticRegression={
#             'C': [1e-14, 1e3],
#             'penalty': ['l1', 'l2', 'elasticnet'],
#             'l1_ratio': [0.0, 1.0],
#             'solver': 'lbfgs',
#         },
#     )
#     ```

# %%
autoclassifier = roicat.classification.classifier.Auto_LogisticRegression(
    X=X,
    y=y,
    params_LogisticRegression={
        'C': [1e-13, 1e3],
    },
    verbose=True,
)

# %% [markdown]
# ##### Run the AutoClassifier

# %%
autoclassifier.fit()
# Out:
# [I 2024-12-18 23:49:03,142] A new study created in memory with name: Autotuner
#   0%|          | 0/150 [00:00<?, ?it/s]
# [I 2024-12-18 23:49:03,485] Trial 0 finished with value: 0.0062560251067180096 and parameters: {'C': 4.90191269558821e-07}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:03,701] Trial 1 finished with value: 0.18556832840901671 and parameters: {'C': 0.026715221799727153}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:03,960] Trial 2 finished with value: 0.017283946406093192 and parameters: {'C': 7.164987410528791e-06}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:04,090] Trial 3 finished with value: 0.3509930523762851 and parameters: {'C': 5.457506372849793e-12}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:04,347] Trial 4 finished with value: 0.6334286129830093 and parameters: {'C': 0.0002612867173647227}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:04,588] Trial 5 finished with value: 0.012054404924210563 and parameters: {'C': 4.833579173616849e-07}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:04,805] Trial 6 finished with value: 0.6864695444794094 and parameters: {'C': 0.00033450686455915174}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:05,084] Trial 7 finished with value: 0.06215603659143423 and parameters: {'C': 9.215574009534502e-06}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:05,263] Trial 8 finished with value: 0.03087485190863017 and parameters: {'C': 9.490127168286742e-10}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:05,509] Trial 9 finished with value: 9.085672544287572 and parameters: {'C': 9.757877110870947}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:05,646] Trial 10 finished with value: 0.1223125888463589 and parameters: {'C': 6.40775610749535e-11}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:05,858] Trial 11 finished with value: 11.72449066465282 and parameters: {'C': 663.7375259848317}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:06,080] Trial 12 finished with value: 0.24656365327409413 and parameters: {'C': 5.713727260192261}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:06,291] Trial 13 finished with value: 1504.174605194 and parameters: {'C': 0.06386504554060012}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:06,516] Trial 14 finished with value: 1.2455962879709768 and parameters: {'C': 29.368256608822108}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:06,772] Trial 15 finished with value: 0.016216413125348425 and parameters: {'C': 1.5729744968916006e-08}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:06,892] Trial 16 finished with value: 0.6739121351263455 and parameters: {'C': 1.0825068635859419e-13}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:07,122] Trial 17 finished with value: 0.01172841413972817 and parameters: {'C': 4.400382404148258e-08}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:07,406] Trial 18 finished with value: 0.009787162662043452 and parameters: {'C': 2.8872966888145642e-08}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:07,606] Trial 19 finished with value: 0.022738262998030043 and parameters: {'C': 2.9699968536635256e-09}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:07,832] Trial 20 finished with value: 0.017831141120984703 and parameters: {'C': 5.500519314878862e-07}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:08,098] Trial 21 finished with value: 0.010762275435420906 and parameters: {'C': 9.104274347916822e-08}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:08,253] Trial 22 finished with value: 0.06519621586458503 and parameters: {'C': 2.644945955220372e-10}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:08,510] Trial 23 finished with value: 0.011631065442998956 and parameters: {'C': 3.7705806749638634e-07}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:08,742] Trial 24 finished with value: 0.5347022772407738 and parameters: {'C': 0.00035511689434647534}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:08,862] Trial 25 finished with value: 0.351735177271454 and parameters: {'C': 5.246357149912681e-12}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:09,086] Trial 26 finished with value: 0.010045473613733332 and parameters: {'C': 3.2907798183142064e-08}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:09,335] Trial 27 finished with value: 0.13576179517807446 and parameters: {'C': 1.7540200487856485e-05}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:09,487] Trial 28 finished with value: 0.20783770001342386 and parameters: {'C': 2.0911037477649305e-11}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:09,716] Trial 29 finished with value: 0.422290741594821 and parameters: {'C': 0.035297630108190474}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:09,920] Trial 30 finished with value: 0.018900548985054808 and parameters: {'C': 6.240557402805504e-09}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:10,169] Trial 31 finished with value: 0.013928050738831034 and parameters: {'C': 1.335862289332361e-07}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:10,462] Trial 32 finished with value: 0.019737413850943256 and parameters: {'C': 1.5534921957159292e-06}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:10,702] Trial 33 finished with value: 0.3372741770162154 and parameters: {'C': 4.659822305855088e-05}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:10,932] Trial 34 finished with value: 0.014469484614708242 and parameters: {'C': 7.63531107518614e-09}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:11,163] Trial 35 finished with value: 0.38641373757610026 and parameters: {'C': 0.0033257166728755116}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:11,456] Trial 36 finished with value: 0.05065768719626292 and parameters: {'C': 3.7033106240622923e-06}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:11,738] Trial 37 finished with value: 0.014203810516817844 and parameters: {'C': 3.637566956618217e-08}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:11,907] Trial 38 finished with value: 0.05184224064570732 and parameters: {'C': 4.3403695629824985e-10}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:12,252] Trial 39 finished with value: 0.014061590306743203 and parameters: {'C': 8.7746166229023e-08}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:12,397] Trial 40 finished with value: 0.5568727629063369 and parameters: {'C': 9.681373466134081e-13}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:12,651] Trial 41 finished with value: 0.007640222442129878 and parameters: {'C': 1.0003764816808852e-06}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:12,903] Trial 42 finished with value: 0.009039558748544698 and parameters: {'C': 1.4076674733338557e-06}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:13,123] Trial 43 finished with value: 0.29110357917284424 and parameters: {'C': 4.1300668621801034e-05}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:13,386] Trial 44 finished with value: 0.020051660811614008 and parameters: {'C': 1.7022974429596073e-06}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:13,651] Trial 45 finished with value: 0.13643219545918908 and parameters: {'C': 0.00016375187974302814}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:13,854] Trial 46 finished with value: 0.03109804633868056 and parameters: {'C': 1.519260511594721e-09}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:14,137] Trial 47 finished with value: 1.1685200092586114 and parameters: {'C': 0.0029813198732263797}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:14,411] Trial 48 finished with value: 0.01246020028014999 and parameters: {'C': 4.3406245281086444e-07}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:14,650] Trial 49 finished with value: 0.04183002725336218 and parameters: {'C': 8.615175958969954e-06}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:14,794] Trial 50 finished with value: 0.07424981358422046 and parameters: {'C': 1.6902855857768137e-10}. Best is trial 0 with value: 0.0062560251067180096.
# [I 2024-12-18 23:49:15,073] Trial 51 finished with value: 0.010324610603296067 and parameters: {'C': 2.5552037468425014e-08}. Best is trial 0 with value: 0.0062560251067180096.
# /opt/conda/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# (LogisticRegression(C=4.90191269558821e-07,
#                     class_weight={np.int64(0): np.float64(0.6404116084977238),
#                                   np.int64(1): np.float64(2.28047956771361)}),
#  {'C': 4.90191269558821e-07})

# %% [markdown]
# # Visualize results

# %%
autoclassifier.plot_C_curve()

# %%
accuracy, confusion_matrix = autoclassifier.evaluate_model()

print(f"Accuracy: {accuracy}")

roicat.visualization.plot_confusion_matrix(
    confusion_matrix=confusion_matrix,
    class_names=None,
)
# Out:
# Accuracy: 0.9978156238430211

# %% [markdown]
# # Save Outputs

# %%
directory_save = '/results/'
filename_prefix_model = 'dendrite'

paths_save = {
    'model':    str(Path(directory_save) / (filename_prefix_model + '.classification_training.autoclassifier' + '.onnx')),
    'run_data': str(Path(directory_save) / (filename_prefix_model + '.classification_training.run_data.richfile')),
}

# %%
autoclassifier.save_model(
    filepath=paths_save['model'],
    allow_overwrite=True,
)

roicat.util.RichFile_ROICaT(path=paths_save['run_data']).save({
    'data': data.__dict__,
    'roinet': roinet.__dict__,
    'accuracy': accuracy,
    'confusion_matrix': confusion_matrix,
}, overwrite=True)
# Out:
# Path: /results/dendrite.classification_training.run_data.richfile (dict)
# ├── 'data':   (dict)
# |    ├── '_system_info':   (dict)
# |    |    ├── 'datetime':   (str)
# |    |    ├── 'roicat':   (dict)
# |    |    |    ├── 'version':   (str)
# |    |    |    ├── 'date_installed':   (str)
# |    |    |
# |    |    ├── 'operating_system':   (dict)
# |    |    |    ├── 'libc_ver':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'win32_is_iot':   (bool)
# |    |    |    ├── 'win32_edition':   (None)
# |    |    |    ├── 'win32_ver':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'mac_ver':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (list)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'java_ver':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (list)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |
# |    |    |    |    ├──   (list)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |
# |    |    |    |
# |    |    |    ├── 'system_alias':   (None)
# |    |    |    ├── 'architecture':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'uname_result':   (None)
# |    |    |    ├── 'uname':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'system':   (str)
# |    |    |    ├── 'node':   (str)
# |    |    |    ├── 'release':   (str)
# |    |    |    ├── 'version':   (str)
# |    |    |    ├── 'machine':   (str)
# |    |    |    ├── 'processor':   (str)
# |    |    |    ├── 'python_implementation':   (str)
# |    |    |    ├── 'python_version':   (str)
# |    |    |    ├── 'python_version_tuple':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'python_branch':   (str)
# |    |    |    ├── 'python_revision':   (str)
# |    |    |    ├── 'python_build':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'python_compiler':   (str)
# |    |    |    ├── 'platform':   (str)
# |    |    |    ├── 'freedesktop_os_release':   (dict)
# |    |    |    |    ├── 'NAME':   (str)
# |    |    |    |    ├── 'ID':   (str)
# |    |    |    |    ├── 'PRETTY_NAME':   (str)
# |    |    |    |    ├── 'VERSION_ID':   (str)
# |    |    |    |    ├── 'VERSION':   (str)
# |    |    |    |    ├── 'VERSION_CODENAME':   (str)
# |    |    |    |    ├── 'ID_LIKE':   (str)
# |    |    |    |    ├── 'HOME_URL':   (str)
# |    |    |    |    ├── 'SUPPORT_URL':   (str)
# |    |    |    |    ├── 'BUG_REPORT_URL':   (str)
# |    |    |    |    ├── 'PRIVACY_POLICY_URL':   (str)
# |    |    |    |    ├── 'UBUNTU_CODENAME':   (str)
# |    |    |    |
# |    |    |
# |    |    ├── 'cpu_info':   (dict)
# |    |    |    ├── 'n_cores':   (int)
# |    |    |    ├── 'brand':   (str)
# |    |    |
# |    |    ├── 'user':   (str)
# |    |    ├── 'ram':   (list)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (float)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |
# |    |    ├── 'gpu_info':   (dict)
# |    |    |    ├── '0':   (dict)
# |    |    |    |    ├── 'id':   (int)
# |    |    |    |    ├── 'uuid':   (str)
# |    |    |    |    ├── 'load':   (float)
# |    |    |    |    ├── 'memoryUtil':   (float)
# |    |    |    |    ├── 'memoryTotal':   (float)
# |    |    |    |    ├── 'memoryUsed':   (float)
# |    |    |    |    ├── 'memoryFree':   (float)
# |    |    |    |    ├── 'driver':   (str)
# |    |    |    |    ├── 'name':   (str)
# |    |    |    |    ├── 'serial':   (str)
# |    |    |    |    ├── 'display_mode':   (str)
# |    |    |    |    ├── 'display_active':   (str)
# |    |    |    |    ├── 'temperature':   (float)
# |    |    |    |
# |    |    |
# |    |    ├── 'conda_env':   (str)
# |    |    ├── 'python':   (str)
# |    |    ├── 'gcc':   (str)
# |    |    ├── 'torch':   (str)
# |    |    ├── 'cuda':   (str)
# |    |    ├── 'cudnn':   (int)
# |    |    ├── 'torch_devices':   (list)
# |    |    |    ├──   (str)
# |    |    |
# |    |    ├── 'pkgs':   (dict)
# |    |    |    ├── 'brotli':   (str)
# |    |    |    ├── 'pysocks':   (str)
# |    |    |    ├── 'archspec':   (str)
# |    |    |    ├── 'boltons':   (str)
# |    |    |    ├── 'cffi':   (str)
# |    |    |    ├── 'charset-normalizer':   (str)
# |    |    |    ├── 'colorama':   (str)
# |    |    |    ├── 'conda':   (str)
# |    |    |    ├── 'conda-libmamba-solver':   (str)
# |    |    |    ├── 'conda-package-handling':   (str)
# |    |    |    ├── 'conda_package_streaming':   (str)
# |    |    |    ├── 'distro':   (str)
# |    |    |    ├── 'frozendict':   (str)
# |    |    |    ├── 'h2':   (str)
# |    |    |    ├── 'hpack':   (str)
# |    |    |    ├── 'hyperframe':   (str)
# |    |    |    ├── 'idna':   (str)
# |    |    |    ├── 'jsonpatch':   (str)
# |    |    |    ├── 'jsonpointer':   (str)
# |    |    |    ├── 'libmambapy':   (str)
# |    |    |    ├── 'mamba':   (str)
# |    |    |    ├── 'menuinst':   (str)
# |    |    |    ├── 'packaging':   (str)
# |    |    |    ├── 'pip':   (str)
# |    |    |    ├── 'platformdirs':   (str)
# |    |    |    ├── 'pluggy':   (str)
# |    |    |    ├── 'pycosat':   (str)
# |    |    |    ├── 'pycparser':   (str)
# |    |    |    ├── 'requests':   (str)
# |    |    |    ├── 'ruamel.yaml':   (str)
# |    |    |    ├── 'ruamel.yaml.clib':   (str)
# |    |    |    ├── 'setuptools':   (str)
# |    |    |    ├── 'truststore':   (str)
# |    |    |    ├── 'urllib3':   (str)
# |    |    |    ├── 'wheel':   (str)
# |    |    |    ├── 'zstandard':   (str)
# |    |    |    ├── 'asciitree':   (str)
# |    |    |    ├── 'dill':   (str)
# |    |    |    ├── 'fasteners':   (str)
# |    |    |    ├── 'hdmf':   (str)
# |    |    |    ├── 'lazy-ops':   (str)
# |    |    |    ├── 'numcodecs':   (str)
# |    |    |    ├── 'pynwb':   (str)
# |    |    |    ├── 'roiextractors':   (str)
# |    |    |    ├── 'zarr':   (str)
# |    |    |    ├── 'gputil':   (str)
# |    |    |    ├── 'gitpython':   (str)
# |    |    |    ├── 'mako':   (str)
# |    |    |    ├── 'markdown':   (str)
# |    |    |    ├── 'pint':   (str)
# |    |    |    ├── 'qtpy':   (str)
# |    |    |    ├── 'sqlalchemy':   (str)
# |    |    |    ├── 'send2trash':   (str)
# |    |    |    ├── 'alembic':   (str)
# |    |    |    ├── 'anyio':   (str)
# |    |    |    ├── 'appdirs':   (str)
# |    |    |    ├── 'argon2-cffi':   (str)
# |    |    |    ├── 'argon2-cffi-bindings':   (str)
# |    |    |    ├── 'arrow':   (str)
# |    |    |    ├── 'asttokens':   (str)
# |    |    |    ├── 'async-lru':   (str)
# |    |    |    ├── 'attrs':   (str)
# |    |    |    ├── 'babel':   (str)
# |    |    |    ├── 'beautifulsoup4':   (str)
# |    |    |    ├── 'bleach':   (str)
# |    |    |    ├── 'bokeh':   (str)
# |    |    |    ├── 'click':   (str)
# |    |    |    ├── 'colorcet':   (str)
# |    |    |    ├── 'coloredlogs':   (str)
# |    |    |    ├── 'colorlog':   (str)
# |    |    |    ├── 'comm':   (str)
# |    |    |    ├── 'configparser':   (str)
# |    |    |    ├── 'contourpy':   (str)
# |    |    |    ├── 'cycler':   (str)
# |    |    |    ├── 'debugpy':   (str)
# |    |    |    ├── 'decorator':   (str)
# |    |    |    ├── 'defusedxml':   (str)
# |    |    |    ├── 'docker-pycreds':   (str)
# |    |    |    ├── 'einops':   (str)
# |    |    |    ├── 'executing':   (str)
# |    |    |    ├── 'fastjsonschema':   (str)
# |    |    |    ├── 'flatbuffers':   (str)
# |    |    |    ├── 'flexcache':   (str)
# |    |    |    ├── 'flexparser':   (str)
# |    |    |    ├── 'fonttools':   (str)
# |    |    |    ├── 'fqdn':   (str)
# |    |    |    ├── 'fsspec':   (str)
# |    |    |    ├── 'gitdb':   (str)
# |    |    |    ├── 'greenlet':   (str)
# |    |    |    ├── 'h11':   (str)
# |    |    |    ├── 'h5py':   (str)
# |    |    |    ├── 'hdbscan':   (str)
# |    |    |    ├── 'holoviews':   (str)
# |    |    |    ├── 'httpcore':   (str)
# |    |    |    ├── 'httpx':   (str)
# |    |    |    ├── 'huggingface-hub':   (str)
# |    |    |    ├── 'humanfriendly':   (str)
# |    |    |    ├── 'hypothesis':   (str)
# |    |    |    ├── 'imageio':   (str)
# |    |    |    ├── 'iniconfig':   (str)
# |    |    |    ├── 'ipykernel':   (str)
# |    |    |    ├── 'ipython':   (str)
# |    |    |    ├── 'ipywidgets':   (str)
# |    |    |    ├── 'isoduration':   (str)
# |    |    |    ├── 'jedi':   (str)
# |    |    |    ├── 'joblib':   (str)
# |    |    |    ├── 'json5':   (str)
# |    |    |    ├── 'jsonschema':   (str)
# |    |    |    ├── 'jsonschema-specifications':   (str)
# |    |    |    ├── 'jupyter':   (str)
# |    |    |    ├── 'jupyter_bokeh':   (str)
# |    |    |    ├── 'jupyter_client':   (str)
# |    |    |    ├── 'jupyter-console':   (str)
# |    |    |    ├── 'jupyter_core':   (str)
# |    |    |    ├── 'jupyter-events':   (str)
# |    |    |    ├── 'jupyter-lsp':   (str)
# |    |    |    ├── 'jupyter_server':   (str)
# |    |    |    ├── 'jupyter_server_terminals':   (str)
# |    |    |    ├── 'jupyterlab':   (str)
# |    |    |    ├── 'jupyterlab_pygments':   (str)
# |    |    |    ├── 'jupyterlab_server':   (str)
# |    |    |    ├── 'jupyterlab_widgets':   (str)
# |    |    |    ├── 'kiwisolver':   (str)
# |    |    |    ├── 'kornia':   (str)
# |    |    |    ├── 'kornia_rs':   (str)
# |    |    |    ├── 'kymatio':   (str)
# |    |    |    ├── 'lazy_loader':   (str)
# |    |    |    ├── 'linkify-it-py':   (str)
# |    |    |    ├── 'llvmlite':   (str)
# |    |    |    ├── 'loguru':   (str)
# |    |    |    ├── 'markdown-it-py':   (str)
# |    |    |    ├── 'mat73':   (str)
# |    |    |    ├── 'matplotlib':   (str)
# |    |    |    ├── 'matplotlib-inline':   (str)
# |    |    |    ├── 'mdit-py-plugins':   (str)
# |    |    |    ├── 'mdurl':   (str)
# |    |    |    ├── 'mistune':   (str)
# |    |    |    ├── 'natsort':   (str)
# |    |    |    ├── 'nbclient':   (str)
# |    |    |    ├── 'nbconvert':   (str)
# |    |    |    ├── 'nbformat':   (str)
# |    |    |    ├── 'nest-asyncio':   (str)
# |    |    |    ├── 'notebook':   (str)
# |    |    |    ├── 'notebook_shim':   (str)
# |    |    |    ├── 'numba':   (str)
# |    |    |    ├── 'numpy':   (str)
# |    |    |    ├── 'nvidia-cublas-cu12':   (str)
# |    |    |    ├── 'nvidia-cuda-cupti-cu12':   (str)
# |    |    |    ├── 'nvidia-cuda-nvrtc-cu12':   (str)
# |    |    |    ├── 'nvidia-cuda-runtime-cu12':   (str)
# |    |    |    ├── 'nvidia-cudnn-cu12':   (str)
# |    |    |    ├── 'nvidia-cufft-cu12':   (str)
# |    |    |    ├── 'nvidia-curand-cu12':   (str)
# |    |    |    ├── 'nvidia-cusolver-cu12':   (str)
# |    |    |    ├── 'nvidia-cusparse-cu12':   (str)
# |    |    |    ├── 'nvidia-nccl-cu12':   (str)
# |    |    |    ├── 'nvidia-nvjitlink-cu12':   (str)
# |    |    |    ├── 'nvidia-nvtx-cu12':   (str)
# |    |    |    ├── 'onnx':   (str)
# |    |    |    ├── 'onnx2torch':   (str)
# |    |    |    ├── 'onnxconverter-common':   (str)
# |    |    |    ├── 'onnxruntime':   (str)
# |    |    |    ├── 'opencv-contrib-python-headless':   (str)
# |    |    |    ├── 'optuna':   (str)
# |    |    |    ├── 'outcome':   (str)
# |    |    |    ├── 'overrides':   (str)
# |    |    |    ├── 'pandas':   (str)
# |    |    |    ├── 'pandocfilters':   (str)
# |    |    |    ├── 'panel':   (str)
# |    |    |    ├── 'param':   (str)
# |    |    |    ├── 'parso':   (str)
# |    |    |    ├── 'pexpect':   (str)
# |    |    |    ├── 'pillow':   (str)
# |    |    |    ├── 'plotly':   (str)
# |    |    |    ├── 'poselib':   (str)
# |    |    |    ├── 'prometheus_client':   (str)
# |    |    |    ├── 'prompt_toolkit':   (str)
# |    |    |    ├── 'protobuf':   (str)
# |    |    |    ├── 'psutil':   (str)
# |    |    |    ├── 'ptyprocess':   (str)
# |    |    |    ├── 'pure_eval':   (str)
# |    |    |    ├── 'py-cpuinfo':   (str)
# |    |    |    ├── 'pygments':   (str)
# |    |    |    ├── 'pynndescent':   (str)
# |    |    |    ├── 'pyparsing':   (str)
# |    |    |    ├── 'pytest':   (str)
# |    |    |    ├── 'python-dateutil':   (str)
# |    |    |    ├── 'python-json-logger':   (str)
# |    |    |    ├── 'pytz':   (str)
# |    |    |    ├── 'pyviz_comms':   (str)
# |    |    |    ├── 'pyzmq':   (str)
# |    |    |    ├── 'qtconsole':   (str)
# |    |    |    ├── 'referencing':   (str)
# |    |    |    ├── 'rfc3339-validator':   (str)
# |    |    |    ├── 'rfc3986-validator':   (str)
# |    |    |    ├── 'richfile':   (str)
# |    |    |    ├── 'roicat':   (str)
# |    |    |    ├── 'romatch_roicat':   (str)
# |    |    |    ├── 'rpds-py':   (str)
# |    |    |    ├── 'safetensors':   (str)
# |    |    |    ├── 'scikit-image':   (str)
# |    |    |    ├── 'scikit-learn':   (str)
# |    |    |    ├── 'scipy':   (str)
# |    |    |    ├── 'seaborn':   (str)
# |    |    |    ├── 'selenium':   (str)
# |    |    |    ├── 'sentry-sdk':   (str)
# |    |    |    ├── 'setproctitle':   (str)
# |    |    |    ├── 'six':   (str)
# |    |    |    ├── 'skl2onnx':   (str)
# |    |    |    ├── 'smmap':   (str)
# |    |    |    ├── 'sniffio':   (str)
# |    |    |    ├── 'sortedcontainers':   (str)
# |    |    |    ├── 'soupsieve':   (str)
# |    |    |    ├── 'sparse':   (str)
# |    |    |    ├── 'stack-data':   (str)
# |    |    |    ├── 'sympy':   (str)
# |    |    |    ├── 'tenacity':   (str)
# |    |    |    ├── 'terminado':   (str)
# |    |    |    ├── 'threadpoolctl':   (str)
# |    |    |    ├── 'tifffile':   (str)
# |    |    |    ├── 'timm':   (str)
# |    |    |    ├── 'tinycss2':   (str)
# |    |    |    ├── 'torch':   (str)
# |    |    |    ├── 'torchaudio':   (str)
# |    |    |    ├── 'torchvision':   (str)
# |    |    |    ├── 'tornado':   (str)
# |    |    |    ├── 'tqdm':   (str)
# |    |    |    ├── 'traitlets':   (str)
# |    |    |    ├── 'trio':   (str)
# |    |    |    ├── 'trio-websocket':   (str)
# |    |    |    ├── 'triton':   (str)
# |    |    |    ├── 'types-python-dateutil':   (str)
# |    |    |    ├── 'tzdata':   (str)
# |    |    |    ├── 'uc-micro-py':   (str)
# |    |    |    ├── 'umap-learn':   (str)
# |    |    |    ├── 'uri-template':   (str)
# |    |    |    ├── 'wandb':   (str)
# |    |    |    ├── 'wcwidth':   (str)
# |    |    |    ├── 'webcolors':   (str)
# |    |    |    ├── 'webencodings':   (str)
# |    |    |    ├── 'websocket-client':   (str)
# |    |    |    ├── 'widgetsnbextension':   (str)
# |    |    |    ├── 'wsproto':   (str)
# |    |    |    ├── 'xxhash':   (str)
# |    |    |    ├── 'xyzservices':   (str)
# |    |    |    ├── 'markupsafe':   (str)
# |    |    |    ├── 'pyyaml':   (str)
# |    |    |    ├── 'certifi':   (str)
# |    |    |    ├── 'filelock':   (str)
# |    |    |    ├── 'gmpy2':   (str)
# |    |    |    ├── 'jinja2':   (str)
# |    |    |    ├── 'mpmath':   (str)
# |    |    |    ├── 'networkx':   (str)
# |    |    |    ├── 'typing_extensions':   (str)
# |    |    |    ├── 'autocommand':   (str)
# |    |    |    ├── 'backports.tarfile':   (str)
# |    |    |    ├── 'importlib_metadata':   (str)
# |    |    |    ├── 'importlib_resources':   (str)
# |    |    |    ├── 'inflect':   (str)
# |    |    |    ├── 'jaraco.context':   (str)
# |    |    |    ├── 'jaraco.functools':   (str)
# |    |    |    ├── 'jaraco.text':   (str)
# |    |    |    ├── 'more-itertools':   (str)
# |    |    |    ├── 'ordered-set':   (str)
# |    |    |    ├── 'tomli':   (str)
# |    |    |    ├── 'typeguard':   (str)
# |    |    |    ├── 'zipp':   (str)
# |    |    |
# |    |
# |    ├── 'params':   (dict)
# |    |    ├── 'set_ROI_images':   (dict)
# |    |    |    ├── 'um_per_pixel':   (list)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |
# |    |    |
# |    |    ├── 'set_class_labels':   (dict)
# |    |    |    ├── 'path_labels':   (None)
# |    |    |    ├── 'n_classes':   (None)
# |    |    |
# |    |
# |    ├── '_verbose':   (bool)
# |    ├── 'n_sessions':   (int)
# |    ├── 'n_roi':   (list)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |
# |    ├── 'n_roi_total':   (int)
# |    ├── 'ROI_images':   (list)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |
# |    ├── 'um_per_pixel':   (list)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |    ├──   (float)
# |    |
# |    ├── 'class_labels_raw':   (list)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |
# |    ├── 'class_labels_index':   (list)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |    ├──   (numpy_array)
# |    |
# |    ├── 'n_classes':   (int)
# |    ├── 'n_class_labels':   (list)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |    ├──   (int)
# |    |
# |    ├── 'n_class_labels_total':   (int)
# |    ├── 'unique_class_labels':   (numpy_array)
# |
# ├── 'roinet':   (dict)
# |    ├── '_system_info':   (dict)
# |    |    ├── 'datetime':   (str)
# |    |    ├── 'roicat':   (dict)
# |    |    |    ├── 'version':   (str)
# |    |    |    ├── 'date_installed':   (str)
# |    |    |
# |    |    ├── 'operating_system':   (dict)
# |    |    |    ├── 'libc_ver':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'win32_is_iot':   (bool)
# |    |    |    ├── 'win32_edition':   (None)
# |    |    |    ├── 'win32_ver':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'mac_ver':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (list)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'java_ver':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (list)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |
# |    |    |    |    ├──   (list)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |    ├──   (str)
# |    |    |    |    |
# |    |    |    |
# |    |    |    ├── 'system_alias':   (None)
# |    |    |    ├── 'architecture':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'uname_result':   (None)
# |    |    |    ├── 'uname':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'system':   (str)
# |    |    |    ├── 'node':   (str)
# |    |    |    ├── 'release':   (str)
# |    |    |    ├── 'version':   (str)
# |    |    |    ├── 'machine':   (str)
# |    |    |    ├── 'processor':   (str)
# |    |    |    ├── 'python_implementation':   (str)
# |    |    |    ├── 'python_version':   (str)
# |    |    |    ├── 'python_version_tuple':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'python_branch':   (str)
# |    |    |    ├── 'python_revision':   (str)
# |    |    |    ├── 'python_build':   (list)
# |    |    |    |    ├──   (str)
# |    |    |    |    ├──   (str)
# |    |    |    |
# |    |    |    ├── 'python_compiler':   (str)
# |    |    |    ├── 'platform':   (str)
# |    |    |    ├── 'freedesktop_os_release':   (dict)
# |    |    |    |    ├── 'NAME':   (str)
# |    |    |    |    ├── 'ID':   (str)
# |    |    |    |    ├── 'PRETTY_NAME':   (str)
# |    |    |    |    ├── 'VERSION_ID':   (str)
# |    |    |    |    ├── 'VERSION':   (str)
# |    |    |    |    ├── 'VERSION_CODENAME':   (str)
# |    |    |    |    ├── 'ID_LIKE':   (str)
# |    |    |    |    ├── 'HOME_URL':   (str)
# |    |    |    |    ├── 'SUPPORT_URL':   (str)
# |    |    |    |    ├── 'BUG_REPORT_URL':   (str)
# |    |    |    |    ├── 'PRIVACY_POLICY_URL':   (str)
# |    |    |    |    ├── 'UBUNTU_CODENAME':   (str)
# |    |    |    |
# |    |    |
# |    |    ├── 'cpu_info':   (dict)
# |    |    |    ├── 'n_cores':   (int)
# |    |    |    ├── 'brand':   (str)
# |    |    |
# |    |    ├── 'user':   (str)
# |    |    ├── 'ram':   (list)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (float)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |
# |    |    ├── 'gpu_info':   (dict)
# |    |    |    ├── '0':   (dict)
# |    |    |    |    ├── 'id':   (int)
# |    |    |    |    ├── 'uuid':   (str)
# |    |    |    |    ├── 'load':   (float)
# |    |    |    |    ├── 'memoryUtil':   (float)
# |    |    |    |    ├── 'memoryTotal':   (float)
# |    |    |    |    ├── 'memoryUsed':   (float)
# |    |    |    |    ├── 'memoryFree':   (float)
# |    |    |    |    ├── 'driver':   (str)
# |    |    |    |    ├── 'name':   (str)
# |    |    |    |    ├── 'serial':   (str)
# |    |    |    |    ├── 'display_mode':   (str)
# |    |    |    |    ├── 'display_active':   (str)
# |    |    |    |    ├── 'temperature':   (float)
# |    |    |    |
# |    |    |
# |    |    ├── 'conda_env':   (str)
# |    |    ├── 'python':   (str)
# |    |    ├── 'gcc':   (str)
# |    |    ├── 'torch':   (str)
# |    |    ├── 'cuda':   (str)
# |    |    ├── 'cudnn':   (int)
# |    |    ├── 'torch_devices':   (list)
# |    |    |    ├──   (str)
# |    |    |
# |    |    ├── 'pkgs':   (dict)
# |    |    |    ├── 'brotli':   (str)
# |    |    |    ├── 'pysocks':   (str)
# |    |    |    ├── 'archspec':   (str)
# |    |    |    ├── 'boltons':   (str)
# |    |    |    ├── 'cffi':   (str)
# |    |    |    ├── 'charset-normalizer':   (str)
# |    |    |    ├── 'colorama':   (str)
# |    |    |    ├── 'conda':   (str)
# |    |    |    ├── 'conda-libmamba-solver':   (str)
# |    |    |    ├── 'conda-package-handling':   (str)
# |    |    |    ├── 'conda_package_streaming':   (str)
# |    |    |    ├── 'distro':   (str)
# |    |    |    ├── 'frozendict':   (str)
# |    |    |    ├── 'h2':   (str)
# |    |    |    ├── 'hpack':   (str)
# |    |    |    ├── 'hyperframe':   (str)
# |    |    |    ├── 'idna':   (str)
# |    |    |    ├── 'jsonpatch':   (str)
# |    |    |    ├── 'jsonpointer':   (str)
# |    |    |    ├── 'libmambapy':   (str)
# |    |    |    ├── 'mamba':   (str)
# |    |    |    ├── 'menuinst':   (str)
# |    |    |    ├── 'packaging':   (str)
# |    |    |    ├── 'pip':   (str)
# |    |    |    ├── 'platformdirs':   (str)
# |    |    |    ├── 'pluggy':   (str)
# |    |    |    ├── 'pycosat':   (str)
# |    |    |    ├── 'pycparser':   (str)
# |    |    |    ├── 'requests':   (str)
# |    |    |    ├── 'ruamel.yaml':   (str)
# |    |    |    ├── 'ruamel.yaml.clib':   (str)
# |    |    |    ├── 'setuptools':   (str)
# |    |    |    ├── 'truststore':   (str)
# |    |    |    ├── 'urllib3':   (str)
# |    |    |    ├── 'wheel':   (str)
# |    |    |    ├── 'zstandard':   (str)
# |    |    |    ├── 'asciitree':   (str)
# |    |    |    ├── 'dill':   (str)
# |    |    |    ├── 'fasteners':   (str)
# ...
# |    |    |    ├── 'panel':   (str)
# |    |    |    ├── 'param':   (str)
# |    |    |    ├── 'parso':   (str)
# |    |    |    ├── 'pexpect':   (str)
# |    |    |    ├── 'pillow':   (str)
# |    |    |    ├── 'plotly':   (str)
# |    |    |    ├── 'poselib':   (str)
# |    |    |    ├── 'prometheus_client':   (str)
# |    |    |    ├── 'prompt_toolkit':   (str)
# |    |    |    ├── 'protobuf':   (str)
# |    |    |    ├── 'psutil':   (str)
# |    |    |    ├── 'ptyprocess':   (str)
# |    |    |    ├── 'pure_eval':   (str)
# |    |    |    ├── 'py-cpuinfo':   (str)
# |    |    |    ├── 'pygments':   (str)
# |    |    |    ├── 'pynndescent':   (str)
# |    |    |    ├── 'pyparsing':   (str)
# |    |    |    ├── 'pytest':   (str)
# |    |    |    ├── 'python-dateutil':   (str)
# |    |    |    ├── 'python-json-logger':   (str)
# |    |    |    ├── 'pytz':   (str)
# |    |    |    ├── 'pyviz_comms':   (str)
# |    |    |    ├── 'pyzmq':   (str)
# |    |    |    ├── 'qtconsole':   (str)
# |    |    |    ├── 'referencing':   (str)
# |    |    |    ├── 'rfc3339-validator':   (str)
# |    |    |    ├── 'rfc3986-validator':   (str)
# |    |    |    ├── 'richfile':   (str)
# |    |    |    ├── 'roicat':   (str)
# |    |    |    ├── 'romatch_roicat':   (str)
# |    |    |    ├── 'rpds-py':   (str)
# |    |    |    ├── 'safetensors':   (str)
# |    |    |    ├── 'scikit-image':   (str)
# |    |    |    ├── 'scikit-learn':   (str)
# |    |    |    ├── 'scipy':   (str)
# |    |    |    ├── 'seaborn':   (str)
# |    |    |    ├── 'selenium':   (str)
# |    |    |    ├── 'sentry-sdk':   (str)
# |    |    |    ├── 'setproctitle':   (str)
# |    |    |    ├── 'six':   (str)
# |    |    |    ├── 'skl2onnx':   (str)
# |    |    |    ├── 'smmap':   (str)
# |    |    |    ├── 'sniffio':   (str)
# |    |    |    ├── 'sortedcontainers':   (str)
# |    |    |    ├── 'soupsieve':   (str)
# |    |    |    ├── 'sparse':   (str)
# |    |    |    ├── 'stack-data':   (str)
# |    |    |    ├── 'sympy':   (str)
# |    |    |    ├── 'tenacity':   (str)
# |    |    |    ├── 'terminado':   (str)
# |    |    |    ├── 'threadpoolctl':   (str)
# |    |    |    ├── 'tifffile':   (str)
# |    |    |    ├── 'timm':   (str)
# |    |    |    ├── 'tinycss2':   (str)
# |    |    |    ├── 'torch':   (str)
# |    |    |    ├── 'torchaudio':   (str)
# |    |    |    ├── 'torchvision':   (str)
# |    |    |    ├── 'tornado':   (str)
# |    |    |    ├── 'tqdm':   (str)
# |    |    |    ├── 'traitlets':   (str)
# |    |    |    ├── 'trio':   (str)
# |    |    |    ├── 'trio-websocket':   (str)
# |    |    |    ├── 'triton':   (str)
# |    |    |    ├── 'types-python-dateutil':   (str)
# |    |    |    ├── 'tzdata':   (str)
# |    |    |    ├── 'uc-micro-py':   (str)
# |    |    |    ├── 'umap-learn':   (str)
# |    |    |    ├── 'uri-template':   (str)
# |    |    |    ├── 'wandb':   (str)
# |    |    |    ├── 'wcwidth':   (str)
# |    |    |    ├── 'webcolors':   (str)
# |    |    |    ├── 'webencodings':   (str)
# |    |    |    ├── 'websocket-client':   (str)
# |    |    |    ├── 'widgetsnbextension':   (str)
# |    |    |    ├── 'wsproto':   (str)
# |    |    |    ├── 'xxhash':   (str)
# |    |    |    ├── 'xyzservices':   (str)
# |    |    |    ├── 'markupsafe':   (str)
# |    |    |    ├── 'pyyaml':   (str)
# |    |    |    ├── 'certifi':   (str)
# |    |    |    ├── 'filelock':   (str)
# |    |    |    ├── 'gmpy2':   (str)
# |    |    |    ├── 'jinja2':   (str)
# |    |    |    ├── 'mpmath':   (str)
# |    |    |    ├── 'networkx':   (str)
# |    |    |    ├── 'typing_extensions':   (str)
# |    |    |    ├── 'autocommand':   (str)
# |    |    |    ├── 'backports.tarfile':   (str)
# |    |    |    ├── 'importlib_metadata':   (str)
# |    |    |    ├── 'importlib_resources':   (str)
# |    |    |    ├── 'inflect':   (str)
# |    |    |    ├── 'jaraco.context':   (str)
# |    |    |    ├── 'jaraco.functools':   (str)
# |    |    |    ├── 'jaraco.text':   (str)
# |    |    |    ├── 'more-itertools':   (str)
# |    |    |    ├── 'ordered-set':   (str)
# |    |    |    ├── 'tomli':   (str)
# |    |    |    ├── 'typeguard':   (str)
# |    |    |    ├── 'zipp':   (str)
# |    |    |
# |    |
# |    ├── 'params':   (dict)
# |    |    ├── '__init__':   (dict)
# |    |    |    ├── 'dir_networkFiles':   (str)
# |    |    |    ├── 'device':   (str)
# |    |    |    ├── 'download_method':   (str)
# |    |    |    ├── 'download_url':   (str)
# |    |    |    ├── 'download_hash':   (str)
# |    |    |    ├── 'names_networkFiles':   (None)
# |    |    |    ├── 'forward_pass_version':   (str)
# |    |    |    ├── 'verbose':   (bool)
# |    |    |
# |    |    ├── 'generate_dataloader':   (dict)
# |    |    |    ├── 'um_per_pixel':   (list)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |    ├──   (float)
# |    |    |    |
# |    |    |    ├── 'nan_to_num':   (bool)
# |    |    |    ├── 'nan_to_num_val':   (float)
# |    |    |    ├── 'pref_plot':   (bool)
# |    |    |    ├── 'batchSize_dataloader':   (int)
# |    |    |    ├── 'pinMemory_dataloader':   (bool)
# |    |    |    ├── 'numWorkers_dataloader':   (int)
# |    |    |    ├── 'persistentWorkers_dataloader':   (bool)
# |    |    |    ├── 'prefetchFactor_dataloader':   (int)
# |    |    |    ├── 'img_size_out':   (tuple)
# |    |    |    |    ├──   (int)
# |    |    |    |    ├──   (int)
# |    |    |    |
# |    |    |    ├── 'jit_script_transforms':   (bool)
# |    |    |
# |    |
# |    ├── '_device':   (str)
# |    ├── '_verbose':   (bool)
# |    ├── '_dir_networkFiles':   (str)
# |    ├── '_download_url':   (str)
# |    ├── '_download_path_save':   (str)
# |    ├── 'params_model':   (dict)
# |    |    ├── 'pref_log_all_steps':   (bool)
# |    |    ├── 'paths':   (dict)
# |    |    |    ├── 'dir_github':   (str)
# |    |    |    ├── 'fileName_save_model':   (str)
# |    |    |    ├── 'path_data_training':   (str)
# |    |    |
# |    |    ├── 'prefs':   (dict)
# |    |    |    ├── 'saveModelIteratively':   (bool)
# |    |    |    ├── 'saveLogs':   (bool)
# |    |    |
# |    |    ├── 'useGPU_training':   (bool)
# |    |    ├── 'useGPU_dataloader':   (bool)
# |    |    ├── 'dataloader_kwargs':   (dict)
# |    |    |    ├── 'batch_size':   (int)
# |    |    |    ├── 'shuffle':   (bool)
# |    |    |    ├── 'drop_last':   (bool)
# |    |    |    ├── 'pin_memory':   (bool)
# |    |    |    ├── 'num_workers':   (int)
# |    |    |    ├── 'persistent_workers':   (bool)
# |    |    |    ├── 'prefetch_factor':   (int)
# |    |    |
# |    |    ├── 'inner_batch_size':   (int)
# |    |    ├── 'torchvision_model':   (str)
# |    |    ├── 'pre_head_fc_sizes':   (list)
# |    |    |    ├──   (int)
# |    |    |    ├──   (int)
# |    |    |
# |    |    ├── 'post_head_fc_sizes':   (list)
# |    |    |    ├──   (int)
# |    |    |
# |    |    ├── 'block_to_unfreeze':   (str)
# |    |    ├── 'n_block_toInclude':   (int)
# |    |    ├── 'head_nonlinearity':   (str)
# |    |    ├── 'lr':   (float)
# |    |    ├── 'penalty_orthogonality':   (float)
# |    |    ├── 'weight_decay':   (float)
# |    |    ├── 'gamma':   (float)
# |    |    ├── 'n_epochs':   (int)
# |    |    ├── 'temperature':   (float)
# |    |    ├── 'l2_alpha':   (float)
# |    |    ├── 'augmentation':   (dict)
# |    |    |    ├── 'Scale_image_sum':   (dict)
# |    |    |    |    ├── 'sum_val':   (int)
# |    |    |    |    ├── 'epsilon':   (float)
# |    |    |    |    ├── 'min_sub':   (bool)
# |    |    |    |
# |    |    |    ├── 'AddPoissonNoise':   (dict)
# |    |    |    |    ├── 'scaler_bounds':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'prob':   (float)
# |    |    |    |    ├── 'base':   (int)
# |    |    |    |    ├── 'scaling':   (str)
# |    |    |    |
# |    |    |    ├── 'Horizontal_stripe_scale':   (dict)
# |    |    |    |    ├── 'alpha_min_max':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'im_size':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'prob':   (float)
# |    |    |    |
# |    |    |    ├── 'Horizontal_stripe_shift':   (dict)
# |    |    |    |    ├── 'alpha_min_max':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'im_size':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'prob':   (float)
# |    |    |    |
# |    |    |    ├── 'RandomHorizontalFlip':   (dict)
# |    |    |    |    ├── 'p':   (float)
# |    |    |    |
# |    |    |    ├── 'RandomAffine':   (dict)
# |    |    |    |    ├── 'degrees':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'translate':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'scale':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'shear':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'interpolation':   (str)
# |    |    |    |    ├── 'fill':   (int)
# |    |    |    |    ├── 'fillcolor':   (None)
# |    |    |    |    ├── 'resample':   (None)
# |    |    |    |
# |    |    |    ├── 'AddGaussianNoise':   (dict)
# |    |    |    |    ├── 'mean':   (int)
# |    |    |    |    ├── 'std':   (float)
# |    |    |    |    ├── 'prob':   (float)
# |    |    |    |
# |    |    |    ├── 'ScaleDynamicRange':   (dict)
# |    |    |    |    ├── 'scaler_bounds':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'epsilon':   (float)
# |    |    |    |
# |    |    |    ├── 'WarpPoints':   (dict)
# |    |    |    |    ├── 'r':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'cx':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'cy':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'dx':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'dy':   (list)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |    ├──   (float)
# |    |    |    |    |
# |    |    |    |    ├── 'n_warps':   (int)
# |    |    |    |    ├── 'prob':   (float)
# |    |    |    |    ├── 'img_size_in':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |    ├── 'img_size_out':   (list)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |    ├──   (int)
# |    |    |    |    |
# |    |    |    |
# |    |    |    ├── 'TileChannels':   (dict)
# |    |    |    |    ├── 'dim':   (int)
# |    |    |    |    ├── 'n_channels':   (int)
# |    |    |    |
# |    |    |
# |    |
# |    ├── 'net':   (torch_module)
# |    ├── 'ROI_images_rs':   (numpy_array)
# |    ├── 'transforms':   (torch_sequence)
# |    ├── 'dataset':   (torch_dataset)
# |    ├── 'dataloader':   (torch_dataloader)
# |    ├── 'latents':   (torch_tensor)
# |
# ├── 'accuracy':   (float)
# ├── 'confusion_matrix':   (numpy_array)
# RichFile(path=/results/dendrite.classification_training.run_data.richfile, check=True, params_load={}, params_save={})
